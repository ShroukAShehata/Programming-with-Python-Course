# %% [markdown]
# # Python Day 1 Practice

# %% [markdown]
# ### 1)Write a Python program which accepts the radius of a circle from the user and compute the area
# #### r = 1.1
# #### Area = 3.8013271108436504

# %%
radius = float(input("enter radius of circle"))
pi = 3.14
print( pi * (radius*radius) )
# Out:
# enter radius of circle4
# 50.24

# %%
import math  #built-in library
radius = float(input("enter radius of circle"))
print( pi * radius**2 )
# Out:
# enter radius of circle4
# 50.24

# %% [markdown]
# ### 2) Write a Python program which accepts a sequence of comma-separated numbers from user and generate a list and a tuple with those numbers.
#
# #### Sample data: 3, 5, 7, 23

# %%
values = str(input("Input some comma seprated numbers : "))
my_list = values.split(",")
my_tuple = tuple(my_list)
print('List : ',my_list)
print('Tuple : ',my_tuple)
# Out:
# Input some comma seprated numbers : 3,4,5,6
# List :  ['3', '4', '5', '6']
# Tuple :  ('3', '4', '5', '6')

# %% [markdown]
# ### 3) Write a Python program to display the first and last colors from the following list. Go to the editor
# #### color_list = ["Red","Green","White" ,"Black"]

# %%
color_list = ["Red","Green","White" ,"Black"]

print(color_list[0])
print(color_list[-1])
# Out:
# Red
# Black

# %% [markdown]
# ### 4)Write a Python program to get the absolute difference between a given number and 17, if the number is greater than 17 return double the absolute difference

# %%
def my_function (n):
    if (n <= 17):
        return (17 - n)
    else:
        return (2 * (n-17))

# %%
my_function(20)
# Out:
# 6

# %%
my_function(14)
# Out:
# 3

# %% [markdown]
# ### 5) Write a Python program to find whether a given number (accept from the user) is even or odd, print out an appropriate message to the user.

# %%
x = int(input("enter a number"))

if (x % 2 == 0):
    print("you entered even number")
else:
    print("you entered odd number")
# Out:
# enter a number3
# you entered odd number

# %% [markdown]
# ### 7) Write a Python program to check whether a specified value is contained in a group of values

# %%
subjects = [ "IT" , "Maths" , "Physics"]
print("IT" in subjects)
# Out:
# True

# %% [markdown]
# ### 8) Make a program to calculate sum of natural numbers up to specific number user enters
# sum = 1+2+3+......+n

# %%
n = int(input("enter number"))
sum = 0 
i = 1

while (i <= n):
    sum = sum + i
    i = i + 1
    
print(sum)
# Out:
# enter number10
# 55

# %% [markdown]
# ### 9) Check if a is the largest number

# %%
a = 200
b = 33
c = 500
if a > b and a > c:
    print("a is the biggest")
else:
    print("a is not the biggest")
# Out:
# a is not the biggest
